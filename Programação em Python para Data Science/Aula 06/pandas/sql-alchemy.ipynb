# %%
! pip show pymysql
# Out:
# Name: PyMySQL
# Version: 1.1.1
# Summary: Pure Python MySQL Driver
# Home-page:
# Author:
# Author-email: Inada Naoki <songofacandy@gmail.com>, Yutaka Matsubara <yutaka.matsubara@gmail.com>
# License: MIT License
# Location: c:\Users\Cleisson\OneDrive - SESISENAISP - Corporativo\Documentos\Python\python data\.venv\Lib\site-packages
# Requires:
# Required-by:

# %%
import sqlalchemy 

conexao = sqlalchemy.create_engine('mysql+pymysql://root:root@localhost:3306/teste', echo=True)

# %%
en = conexao.connect()

sql = sqlalchemy.text('show databases;')
resultado = en.execute(sql)
for i in resultado:
    print(i[0])
# Out:
# 2025-05-04 22:36:53,310 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2025-05-04 22:36:53,318 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-05-04 22:36:53,322 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2025-05-04 22:36:53,323 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-05-04 22:36:53,324 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2025-05-04 22:36:53,326 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-05-04 22:36:53,330 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-04 22:36:53,331 INFO sqlalchemy.engine.Engine show databases;
# 2025-05-04 22:36:53,333 INFO sqlalchemy.engine.Engine [generated in 0.00326s] {}
# information_schema
# mysql
# olimpiadas
# performance_schema
# sakila
# sys
# teste
# world
