# %% [markdown]
# # Python: Variaveis e Tipos de Dados
#
# - Caderno da Aula do dia 09/08/2025

# %%
# !dir # Comandpo para listar o Diretorio
# Out:
#  O volume na unidade C n�o tem nome.
#  O N�mero de S�rie do Volume � F846-FCBF
#
#  Pasta de c:\Users\FIC-TI Especifico\Documents\Cleisson
#
# 09/08/2025  14:43    <DIR>          .
# 09/08/2025  14:41    <DIR>          ..
# 09/08/2025  14:43                 0 aula1.ipynb
#                1 arquivo(s)              0 bytes
#                2 pasta(s)   325.552.820.224 bytes dispon�veis

# %%
print ('Estou usando o Jupyter Notebook no VScode')

nome = 'Cleisson'
sobrenome = 'Morato' 
idade = 30

print (f'Ola {nome} {sobrenome}, seja bem vindo ao Senai MK')
print ('Ola ' + nome + " "+ sobrenome + ' seja bem vindo ao Senai MK')
print ('Ola', nome ,  sobrenome , 'seja bem vindo ao Senai MK')

print ('Ola %s %s, seja bem vindo ao SENAI MK' % (nome , sobrenome))

print ('Eu me chamo %s %s e tenho a idade de %i anos' % (nome, sobrenome, idade) )
# Out:
# Estou usando o Jupyter Notebook no VScode
# Ola Cleisson Morato, seja bem vindo ao Senai MK
# Ola Cleisson Morato seja bem vindo ao Senai MK
# Ola Cleisson Morato seja bem vindo ao Senai MK
# Ola Cleisson Morato, seja bem vindo ao SENAI MK
# Eu me chamo Cleisson Morato e tenho a idade de 30 anos

# %% [markdown]
# - Converta as expresoes matematicas para que possam ser calculadas com o Python:
#
# - 10 + 20 * 30
# - 4² / 30
# - (9³ + 2) x 6 - 1

# %%
valor = 10 + 20 * 30 
valor2 = 4**2 / 30
valor3 = (9**3 +2) * 6 - 1

print (f'O Resultado são: \n{valor} \n{valor2:.2f} \n{valor3}')
# Out:
# O Resultado são:
#  610
#  0.53
#  4385

# %% [markdown]
# - Faça um programa, que exiba o seu nome na tela (usando variaveis)
#
# - Escreva um programa que exiba o resultado de 2a x 3b, onde A vale 3 e B vale 5
#
# - Escreva um programa que calcule a soma de três variaveis e exiba o resultado na Tela
#
# - Faça um programa para calcular o aumento de uma salario informado na variavel (R$ 2000)  de 15 %

# %%
nome = 'cleisson'
print (f'Meu nome na Tela {nome}')
# Out:
# Meu nome na Tela cleisson

# %%
a = 3
b = 5
print (f'O Resultado de 2a x 3b é {2*a*3*b}')
# Out:
# O Resultado de 2a x 3b é 90

# %%
valor_1 = 20
valor_2 = -10
valor_3 = 40

soma = valor_1 + valor_2 + valor_3

print ('O Resultado da soma das variaveis ', valor_1 , valor_2 , valor_3, 'é:' , soma)
# Out:
# O Resultado da soma das variaveis  20 -10 40 é: 50

# %%
salario = 2000
aumento = salario * (0.15)

print (f'Em um salario de R${salario} o aumento de 15% equivale R${aumento:.2f} ')
# Out:
# Em um salario de R$2000 o aumento de 15% equivale R$300.00
