# %% [markdown]
# # Exemplos de aplicação de listas

# %%
nomeLista = []
z = [15,8,9]
z[0] = 7
print(z)

exemplo = [10,50,5,2,100] #lista numerica
Exemplo = ["Python", "é", 'muito', 'bom', 'e facil'] #lista string

#Ambos são listas mesmo com o conteudo seja diferente
print(type(Exemplo))
print(type(exemplo))

# %%
Alunos = []

for x in range(3):
    Alunos.append(input('Digite o nome do aluno: '))
    x += 1
print(Alunos)

# %%
frutas = ['maça', 'banana', 'laranja']

# %%
minhaLista = list(range(10))
print(minhaLista)

minhaLista2= ['2','3','4','5']
print(minhaLista2)

# %%
print(frutas[1])

# %%
sualista = list(range(0,5))
print(len(sualista))

# %%
sualista[1]= "Troquei a posição 1 da lista"
i = 0

while i < len(sualista):
    print(sualista[i])
    i += 1

# %%
umaLista = []

umaLista.append('Carlos')
umaLista.append('João')
umaLista.append('Franciele')
umaLista.append('Paula')
umaLista.append('Janete')

i = 0

while i < len(umaLista):
    print(umaLista[i])
    i += 1

# %%
frutas.append("uva")

# %%
sualista = list(range(0,5))
del sualista[2]

i = 0

while i < len(sualista):
    print(sualista[i])
    i += 1

# %%
i=0
elementoRemovido = sualista.pop(1)
print(f'Removido: {elementoRemovido}')
while i < len(sualista):
    print(sualista[i])
    i += 1

# %%
elementoRemovido = frutas.pop(1)
print(f'O elemento removido da lista de frutas foi: {elementoRemovido}')
